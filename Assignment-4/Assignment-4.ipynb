# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Generate 50 random values from two normal distributions
mu1, sigma1 = 50, 10  # Mean and standard deviation for group 1
mu2, sigma2 = 55, 12  # Mean and standard deviation for group 2

data1 = np.random.normal(mu1, sigma1, 50)  # Sample 1
data2 = np.random.normal(mu2, sigma2, 50)  # Sample 2

# Perform a two-sample t-test
t_stat, p_value = stats.ttest_ind(data1, data2)

# Print the results
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret results at 0.05 significance level
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The means are significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference between means.")

# Plot histograms
plt.hist(data1, alpha=0.5, label="Group 1 (μ1=50, σ1=10)")
plt.hist(data2, alpha=0.5, label="Group 2 (μ2=55, σ2=12)")
plt.axvline(np.mean(data1), color='blue', linestyle='dashed', linewidth=1)
plt.axvline(np.mean(data2), color='red', linestyle='dashed', linewidth=1)
plt.legend()
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Two Normal Distributions")
plt.show()
# Out:
# T-statistic: -3.7600
# P-value: 0.0003
# Reject the null hypothesis: The means are significantly different.
